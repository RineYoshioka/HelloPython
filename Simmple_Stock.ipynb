# %% [markdown]
# <a href="https://colab.research.google.com/github/RineYoshioka/HelloPython/blob/master/Simmple_Stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SoftBank Stock data from Stooq.com 
# reference https://seanmemo.com/234/

import datetime
from pandas_datareader import data
dt2 = datetime.datetime.now()
dt1 = dt2 - datetime.timedelta(weeks=2)
start = dt1.strftime('%Y-%m-%d')
end = dt2.strftime('%Y-%m-%d')
df = data.DataReader('9984.JP', 'stooq', start, end)

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df
# Out:
#             Open  High   Low  Close    Volume
# Date
# 2023-04-25  5039  5065  5018   5030   5705100
# 2023-04-24  5035  5119  5032   5054   8114700
# 2023-04-21  5025  5050  4975   4996   9374800
# 2023-04-20  5132  5141  5061   5094   8067900
# 2023-04-19  5190  5235  5139   5179   7132800
# 2023-04-18  5150  5214  5148   5186   6534000
# 2023-04-17  5120  5178  5120   5173   6198700
# 2023-04-14  5228  5229  5091   5120  11312800
# 2023-04-13  5145  5273  5121   5128  10389800
# 2023-04-12  5223  5311  5171   5178   9752200
