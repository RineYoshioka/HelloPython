# %% [markdown]
# <a href="https://colab.research.google.com/github/RineYoshioka/HelloPython/blob/master/Simmple_Stock230524.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# JRE,JRW,JRC Stock data from Stooq.com 
# reference https://seanmemo.com/234/

import datetime
from pandas_datareader import data
dt2 = datetime.datetime.now()
dt1 = dt2 - datetime.timedelta(weeks=2)
start = dt1.strftime('%Y-%m-%d')
end = dt2.strftime('%Y-%m-%d')
df1 = data.DataReader('9020.JP', 'stooq', start, end)
df2 = data.DataReader('9021.JP', 'stooq', start, end)
df3 = data.DataReader('9022.JP', 'stooq', start, end)

# %%
df1['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df3
# Out:
#              Open   High    Low  Close   Volume
# Date
# 2023-05-23  17280  17335  17075  17155   805500
# 2023-05-22  17040  17330  17040  17330   730100
# 2023-05-19  17300  17315  16985  17035  1050700
# 2023-05-18  17530  17580  17260  17320  1023200
# 2023-05-17  17185  17485  17165  17485   915700
# 2023-05-16  17100  17210  17030  17210   886000
# 2023-05-15  17055  17080  16945  17080   611500
# 2023-05-12  16890  17000  16725  17000  1014200
# 2023-05-11  16720  16785  16660  16710   690600
# 2023-05-10  16880  16885  16680  16785   737900

# %%
df = df2[['Open','High','Low','Close']]
df.plot()
# Out:
# <Axes: xlabel='Date'>
